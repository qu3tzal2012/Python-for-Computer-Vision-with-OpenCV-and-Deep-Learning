# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def display(img,cmap='gray'):
  fig = plt.figure(figsize=(12,10))
  ax = fig.add_subplot(111)
  ax.imshow(img,cmap='gray')

# %%
sep_coins = cv2.imread('pennies.jpg')
display(sep_coins)

# %%
sep_blur = cv2.medianBlur(sep_coins,cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-f337b238e6de> in <module>
# ----> 1 sep_blur = cv2.medianBlur(sep_coins,cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/imgproc/src/smooth.cpp:5179: error: (-215:Assertion failed) (ksize % 2 == 1) && (_src0.dims() <= 2 ) in function 'medianBlur'

# %%
display(sep_coins)

# %%
gray_sep_coins = cv2.cvtColor(sep_blur,cv2.COLOR_BGR2GRAY)

# %%
display(gray_sep_coins)

# %%
ret,sep_thresh = cv2.threshold(gray_sep_coins,160,255,cv2.THRESH_BINARY_INV)

# %%
display(sep_thresh)

# %%
image, contours,hierarchy = cv2.findContours(sep_thresh.copy(),cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

# %%
for i in range(len(contours)):
    if hierarchy[0][i][3] == -1:
        cv2.drawContours(sep_coins,contours,1,(255,0,0),10)
