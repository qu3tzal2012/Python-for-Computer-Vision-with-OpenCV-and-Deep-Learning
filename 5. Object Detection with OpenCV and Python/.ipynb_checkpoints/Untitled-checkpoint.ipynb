# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
full = cv2.imread('sammy.jpg')
full = cv2.cvtColor(full,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %%
full.shape
# Out:
# (1367, 1025, 3)

# %%
face = cv2.imread('sammy_face.jpg')
face = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(face)

# %%
eval
# Out:
# 6

# %%
# all 6 methods will be used to comapre template matching results

methods = ['cv2.TM_CCOEFF','cv2.TM_CCOEFF_NORMED','cv2.TM_CCORR','cv2.TM_CCORR_NORMED','cv2.TM_SQDIFF','cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    # Create a copy
    full_copy = full.copy()
    
    method = eval(m)
    
    # Template matching
    res = cv2.matchTemplate(full_copy,face,method)
    
    min_value,max_value,min_loc = cv2.minMaxLoc(res)
    
    if method in [cv2.TM_SQDIFF,cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
        
    height, width, channels = face.shape
    
    bottom_right = (top_left[0]+width, top_left[1]+height)
    
    cv2.rectangle(full_copy,top_left,bottom_right,(255,0,0),10)
    
    # Plot and show the images
    
    plt.subplot(121)
    plt.imshow(res)
    plt.title('HEATMAP OF TEMPLATE MATCHING')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('DETECTION OF TEMPLATE')
    # Title with the method used
    plt.suptitle(m)
    plt.show()
    
    
    print('\n', '\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e6cc87e9bc37> in <module>
#       6
#       7     # Template matching
# ----> 8     res = cv2.matchTemplate(full_copy,face,methods)
#       9
#      10     min_value,max_value,min_loc = cv2.minMaxLoc(res)
#
# TypeError: an integer is required (got type list)

# %%
my_method = eval('cv2.TM_CCOEFF')
res = cv2.matchTemplate(full,face,my_method)

# %%
plt.imshow(res)

# %%
res.max()
# Out:
# 3058840600.0

# %%
res.min()
# Out:
# -907076700.0
