# %%
import cv2

# %%
img1 = cv2.imread('giraffes.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)
img2 = cv2.imread('bricks.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)

# %%
import matplotlib.pyplot as plt

# %%
img1.shape
# Out:
# (1405, 933, 3)

# %%
img2.shape
# Out:
# (950, 1267, 3)

# %% [markdown]
# resize images

# %%
img1 = cv2.resize(img1,(1400,1400))
img2 = cv2.resize(img2,(1400,1400))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.5,src2=img2,beta=0.9,gamma=0)

# %%
plt.imshow(blended)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.5,src2=img2,beta=0.9,gamma=0)
plt.imshow(blended)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.9,src2=img2,beta=0.6,gamma=0)

# %%
plt.imshow(blended)

# %%
img1 = cv2.imread('giraffes.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)
img2 = cv2.imread('bricks.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + large_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
plt.imshow(large_img)

# %%
import cv
import matplotlib.pyplot as plt

img1 = cv2.imread('giraffes.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_RGB2BGR)
img2 = cv2.imread('bricks.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_RGB2BGR)

img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1405, 933, 3)

# %%
x_offset = 934 - 600
y_offset = 1401 - 600

# %%
img2.shape
# Out:
# (600, 600, 3)

# %% [raw]
# rows

# %%
rows,cols,channels = img2.shape

# %%
rows
# Out:
# 600

# %%
cols
# Out:
# 600

# %%
roi = img1[y_offset:1401,x_offset:943]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray)

# %%
mask_inv = cv2.bitwise_not(img2gray)
plt.imshow(mask_inv)

# %%
plt.imshow(mask_inv,cmap="gray")

# %%
import numpy as np

# %%
white_background = np.full(img2.shape,255,dtype=np.uint8)

# %%
plt.imshow(white_background)

# %%
bk = cv2.bitwise_or(white_background,white_background,mask=mask_inv)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2,img2,mask=mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi = cv2.bitwise_or(roi,fg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-45-6ccc7b17eef8> in <module>
# ----> 1 final_roi = cv2.bitwise_or(roi,fg)
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/9523d527-1b9e-48e0-7ed0-a36adde286f0/volume/opencv-suite_1535558719691/work/modules/core/src/arithm.cpp:225: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'binary_op'
